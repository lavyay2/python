# %% [markdown]
# Questions and Answers
#
# File Handling and Exception Handling
#
# 1 What is the difference between interpreted and compiled languages?
#
# Interpreted: Code is executed directly, line by line. Examples: Python, JavaScript.
# Compiled: Code is translated into machine code before execution. Examples: C++, Java.
# 2 What is exception handling and the purpose of the finally block?
#
# Exception Handling: A mechanism to manage errors and unexpected events.
# finally Block: Ensures code execution regardless of exceptions, often for cleanup tasks.
# 3 What is logging and its purpose?
#
# Logging: Records events and messages for debugging, monitoring, and auditing.
# 4 What is the __del__ method?
#
# __del__ Method: A destructor called before garbage collection for final cleanup.
# Import/From Import
#
# 5 What is the difference between import and from import?
# import: Imports an entire module.
# from import: Imports specific attributes from a module.
# Exception Handling
#
# 6 How can you handle multiple exceptions?
#
# Use multiple except blocks to handle different exception types.
# What is the purpose of the with statement?
#
# Ensures proper resource management (e.g., file closing).
# Multithreading/Multiprocessing
#
# 7What is the difference between multithreading and multiprocessing?
# Multithreading: Multiple threads within a single process, sharing memory.
# Multiprocessing: Multiple processes, each with its own memory space.
# Logging
#
# 8 What are the advantages of logging?
# Debugging, monitoring, and auditing.
# Memory Management
#
# 9What is memory management?
# Allocating and deallocating memory for objects.
# 10 What are the basic steps in exception handling?
# try, except, else, and finally blocks.
# 11 Why is memory management important?
# Prevents memory leaks and optimizes performance.
# 12 What is the role of the try and except blocks?
# try block contains code that might raise exceptions, while except handles them.
# 13 What is garbage collection?
# Python's automatic memory management system.
# 14 What is the purpose of the else block?
# Executes if no exception is raised within the try block.
# 15 What are common logging levels?
# DEBUG, INFO, WARNING, ERROR, and CRITICAL.
# Multiprocessing/Multithreading
#
# 16 What is the difference between os.fork() and multiprocessing?
# os.fork() creates a child process, while multiprocessing provides a higher-level interface for managing processes.
# File Handling
#
# 17 Why is it important to close files?
# To release system resources and prevent leaks.
# 18 What is the difference between file.read() and file.readline()?
# file.read() reads the entire file, while file.readline() reads a single line.
# Logging
#
# 19 What is the logging module?
# Provides a flexible framework for logging messages.
# File Handling
#
# 20 What is the os module?
# Used for file and directory operations.
# Memory Management
#
# 21 What are the challenges in memory management?
# Reference counting and potential memory leaks.
# 22 How do you raise an exception manually?
# Use the raise statement.
# Multithreading
#
# Why is multithreading important?
# Improves performance for CPU-bound and I/O-bound tasks.

# %% [markdown]
# pratical questions  pwskills

# %%
#1. How can you open a file for writing in Python and write a string to it?

Python
file = open("my_file.txt", "w")
file.write("This is a line of text.\n")
file.close()
Use code with caution.

#2. Write a Python program to read the contents of a file and print each line.

Python
with open("my_file.txt", "r") as file:
    for line in file:
        print(line.rstrip())
Use code with caution.

#3. How would you handle a case where the file doesn't exist while trying to open it for reading?

Python
try:
    with open("my_file.txt", "r") as file:
        # File exists, read content
        for line in file:
            print(line.rstrip())
except FileNotFoundError:
    print("File not found.")
Use code with caution.

#4. Write a Python script that reads from one file and writes its content to another file.

Python
with open("source_file.txt", "r") as source, open("destination_file.txt", "w") as dest:
    for line in source:
        dest.write(line)
Use code with caution.

#5. How would you catch and handle a division by zero error in Python?

Python
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero")
Use code with caution.

#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

Python
import logging

logging.basicConfig(filename='error.log', level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Division
 by zero error")
Use code with caution.

#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

Python
import logging

logging.basicConfig(filename='my_log.log', level=logging.DEBUG)

logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')

Use code with caution.

#8. Write a program to handle a file opening error using exception handling.

Python
try:
    with open("nonexistent_file.txt", "r") as file:
        # File exists, read content
        for line in file:
            print(line.rstrip())
except FileNotFoundError:
    print("File not found.")
Use code with caution.

#9. How can you read a file line by line and store its content in a list in Python?

Python
lines = []
with open("my_file.txt", "r") as file:
    for line in file:
        lines.append(line.rstrip())
Use code with caution.

#10. How can you append data to an existing file in Python?

Python
with open("my_file.txt", "a") as file:
    file.write("This line will be appended.\n")
Use code with caution.

11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

Python
my_dict = {'a': 1, 'b': 2}

try:
    value = my_dict['c']
except KeyError:
    print("Key not found")
Use code with caution.

#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

Python
try:
    x = int(input("Enter a number: "))
    y = 10 / x
except ValueError:
    print("Invalid input. Please enter a number.")
except ZeroDivisionError:
    print("Error: Division by zero")
Use code with caution.

#13. How would you check if a file exists before attempting to read it in Python?

Python
import os

if os.path.isfile("my_file.txt"):
    with open("my_file.txt", "r") as file:
        # File exists, read content
        for line in file:
            print(line.rstrip())
else:
    print("File not found.")
Use code with caution.

#14. Write a program that uses the logging module to log both informational and error messages.

Python
import logging

logging.basicConfig(filename='my_log.log', level=logging.DEBUG)

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error")

logging.info("This is an informational message")
Use code with caution.

#15. Write a Python program that prints the content of a file and handles the case when the file is empty.

Python
with open("my_file.txt", "r") as file:
    lines = file.readlines()
    if lines:
        for line in lines:
            print(line.rstrip())
    else:
        print("File is empty")
Use code with caution.

#16. Demonstrate how to use memory profiling to check the memory usage of a small program.

Python
import memory_profiler

@memory_profiler.profile()
def my_function():
    # Your code here

my_function()
Use code with caution.

#17. Write a Python program to create and write a list of numbers to a file, one number per line.

Python
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(str(number) + "\n")
Use code with caution.

#18. How would you implement a basic logging setup that logs to a file with rotation after a certain size?

Python
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler('my_log.log', maxBytes=10240, backupCount=5)
handler.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

logger
 = logging.getLogger(__name__)
logger.addHandler(handler)

logger.info('This
 is an informational message')
Use code with caution.

#19. Write a program that handles both IndexError and KeyError using a try-except block.

Python
my_list = [1, 2, 3]
my_dict = {'a': 1, 'b': 2}

try:
    x = my_list[5]
    y = my_dict['c']
except (IndexError, KeyError) as e:
    print(f"Error: {e}")
Use code with caution.

Let me know if you have any more questions or if you need assistance with more specific tasks!


Sources and related content
wenku.csdn.net
wenku.csdn.net
sematext.com
sematext.com
stackoverflow.com
stackoverflow.com
github.com
github.com






do same thing with this



Show drafts


Certainly, let's address the remaining questions:

#20. How would you open a file and read its contents using a context manager in Python?

Python
with open("my_file.txt", "r") as file:
    contents = file.read()
    print(contents)
Use code with caution.

#21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

Python
def count_word_occurrences(filename, word):
    with open(filename, "r") as file:
        contents = file.read()
        count = contents.count(word)
        print(f"The word '{word}' appears {count} times in the file.")

count_word_occurrences("my_file.txt", "hello")
Use code with caution.

#22. How can you check if a file is empty before attempting to read its contents?

Python
import os

if os.path.getsize("my_file.txt") == 0:
    print("The file is empty.")
else:
    with open("my_file.txt", "r") as file:
        # Read contents
Use code with caution.

#23. Write a Python program that writes to a log file when an error occurs during file handling.

Python
import logging

logging.basicConfig(filename='error.log', level=logging.ERROR)

try:
    with open("nonexistent_file.txt", "r") as file:
        # File exists, read content
        for line in file:
            print(line.rstrip())
except FileNotFoundError:
    logging.error("File not found.")
Use code with caution.

Let me know if you have any other questions or need further assistance!
